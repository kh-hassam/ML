# %%
class uni:
    camp=5#	--- public
    __camp=5#	-- private
    _camp=5#	-- protected
    def __init__(self,name,loc):#----constructor
        self.name=name#	--local name updated
        self.loc=loc
    def display(self):
        print("NAme is",self.name+"location",self.loc)
        print (f"Name is {self.name} and location is {self.loc}")
obj1=uni("FAST","ISB")
obj1.display()
obj1.camp=6
print(obj1.camp)#	-------6
obj2=uni("FAT","IB")
print(obj2.camp)#	-------5
# Out:
# NAme is FASTlocation ISB
# Name is FAST and location is ISB
# 6
# 5

# %%
class Department(uni):#	--- inheritance
    def __init__(self,name,prog,u_name,u_loc):
        super().__init__(u_name,u_loc)#		----uses child class
        self.prog=prog
    def display(self):
        super().display()
        print("NAme is",self.name+"location",self.prog)

# %%
obj1=Department("AI","5","G","I")
obj1.display()
# Out:
# NAme is Glocation I
# Name is G and location is I
# NAme is Glocation 5

# %%
l1=['WOW HAMZAW','XCAT MEOW','POP UP kkk']
for i, value in enumerate(l1,6):
    print(i,value)
# Out:
# 6 WOW HAMZAW
# 7 XCAT MEOW
# 8 POP UP kkk

# %%
def c():
    count=0
    for i in l1:
        l=i.split(" ")
        if len(l)>=2 and i[0]==i[-1]:
            count=count+1
    return(count)
co=c()
co
# Out:
# 1

# %%
l2=[]
for i in l1:
    if i[0]=='X':
        l2.append(i)
        l1.remove(i)
l1=sorted(l1)

# %%
l1=l2+l1
l1
# Out:
# ['XCAT MEOW', 'POP UP kkk', 'WOW HAMZAW']

# %%
#task 4
l3=[1,2,3,3,3]
l4=[]
def v():
    for i in range(len(l3)):
        if i==0:
            l4.append(l3[i])
        elif l3[i]==l3[i-1]:
            continue
        else:
                l4.append(l3[i])
    return l4

# %%
l3=v()
l3
# Out:
# [1, 2, 3]

# %%
#task5
l1=[1,3,4,5]
l2=[4,5,6,7]
l3=l1+l2
l3=sorted(l3)
l3
# Out:
# [1, 3, 4, 4, 5, 5, 6, 7]

# %%
#task 3
tupl=[(1,7),(1,4)]
tupl.sort(key = lambda h: h[1])
tupl
# Out:
# [(1, 4), (1, 7)]

# %% [markdown]
# # pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("drinks.csv")

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df.count()
# Out:
# country                         193
# beer_servings                   193
# spirit_servings                 193
# wine_servings                   193
# total_litres_of_pure_alcohol    193
# continent                       170
# dtype: int64

# %%
df=df.dropna()

# %%
def col(c):
    print(df[c])
col("country")
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3          Andorra
# 4           Angola
#           ...
# 188      Venezuela
# 189        Vietnam
# 190          Yemen
# 191         Zambia
# 192       Zimbabwe
# Name: country, Length: 170, dtype: object

# %%
his=df.plot.hist(bins=190, alpha=0.9)

# %%
df.plot.scatter(x='country',y='wine_servings',s=80)
# Out:
# <AxesSubplot:xlabel='country', ylabel='wine_servings'>

# %%
df.plot.pie(y='wine_servings',figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='wine_servings'>

# %%
df.plot.bar(x='country',y='wine_servings')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(df["wine_servings"], df["beer_servings"], df["spirit_servings"])
plt.show()
